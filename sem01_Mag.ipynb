# %% [markdown]
# #### Задача 1.
#
# Классическое приветствие! Напишите программу, которая спросит у человека, как его зовут, и скажет ему в ответ, "Привет, <имя человека>!". Обратите внимание: перед восклицательным знаком не должно быть пробела.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Запросите у пользователя его ФИО в три отдельных строки, а затем выведите полученные данные в одну строку, не используя конкатенацию.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Напишите программу, которая спрашивает год рождения пользователя (целое число), вычисляет, сколько ему исполнится лет в 2030 году, и выдает полученный результат также в виде целого числа.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Нужно написать программу, которая запрашивает у пользователя два целых числа от 1 до 9 и выводит третье число, количество разрядов которого равняется первому числу, а цифры в разрядах - второму числу.
#
# **Подсказка:** Используйте умножение строки на число.

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Напишите программу, которая по номеру курса студента вычисляет, сколько лет ему еще осталось учиться в бакалавриате, и выводит соответствующее сообщение. Гарантируется, что студент не является выпускником этого года, т.е. не учится на 4 курсе.
#
# Пользователь вводит число (int) от 1 до 3. В качестве ответа программа должна выдать одну из следующих строк:
#
# "Тебе еще учиться 3 года"
#
# "Тебе еще учиться 2 года"
#
# "Тебе еще учиться 1 год"
#
# **Усложнение:** Попробуйте сделать это, НЕ используя условную конструкцию.

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# С клавиатуры вводится температура человека в градусах Цельсия (с точностью до десятых). Нужно определить, какая у него температура в градусах Фаренгейта, учитывая только целую часть, и вывести результат на экран.
#
# Формула подсчета: Цельсий * 1,8 + 32 = Фаренгейт

# %%
# your code here

# %% [markdown]
# #### Задача 7.
#
# Вводится четырехзначное число - год: проверьте, является ли введенный год високосным. Выведите на экран соответствующее сообщение. Используйте условную конструкцию.

# %%
# your code here

# %% [markdown]
# #### Задача 8.
#
# Пользователь вводит три целых числа (в столбик). Нужно написать программу, которая найдет максимальное из этих чисел и выведет его на экран.

# %%
# your code here

# %% [markdown]
# #### Задача 9.
#
# С клавиатуры вводится три числа: доход самого богатого и самого бедного жителя города N, а также средний доход в этом городе. Нужно узнать, кто из них ближе к среднему - богатый или бедный. Выведите в качестве ответа одно слово, либо "богатый", либо "бедный", либо "одинаково" (если и богатый и бедный одинаково близко к среднему). Гарантируется, что первое число минимальное из трех, а второе максимальное.

# %%
# your code here

# %% [markdown]
# #### Задача 10.
#
# С клавиатуры вводится день рождения пользователя в формате ДД.ММ. Вам нужно узнать, прошел ли его день рождения в этом году. Если прошел, напечатайте строку "С прошедшим днем рождения!". Если день рождения пользователя сегодня, напечатайте строку "Поздравление имениннику!". В ином случае ничего не выводите на экран. Сегодняшнее число укажите в коде в виде константы в произвольном формате.
#
# **Примечание:** Не забудьте про високосные годы!

# %%
# your code here

# %% [markdown]
# #### Задача 11 (*) - на креатив.
#
# Придумайте сами задачу, для решения которой нужно будет использовать print() c параметром end="". Напишите в комментарии условие, а затем код, который решает эту задачу.

# %%
# your code here

# %% [markdown]
# #### Задача 12 (**) - на сообразительность.
#
# Напишите программу, реализующую задачу математически правильного округления числа с одним знаком после точки до целого. Используйте только арифметические операции и преобразование типов.

# %%
# your code here

# %% [markdown]
# #### Задача 13 (**) - на оптимизацию.
#
# Иван, Петр и Андрей постоянно занимают друг у друга деньги и уже запутались в своих взаимных расчетах. С клавиатуры вводится последовательно три числа: сколько Иван должен Петру, сколько Петр должен Андрею и сколько Андрей должен Ивану. Вам нужно написать программу, которая поможет произвести между ними взаимозачет так, чтобы им нужно было передать между собой минимально возможные суммы минимальное количество раз, но при этом чтобы каждый в итоге получил ровно то, что ему причитается.

# %%
# your code here
